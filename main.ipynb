# %%
# !pip install kaggle
# import kaggle
# !kaggle datasets download -d balraj98/deepglobe-road-extraction-dataset 
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\asus\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\asus\anaconda3\lib\site-packages (from opencv-python) (1.26.2)

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers.legacy import Adam
import matplotlib.pyplot as plt
import cv2

from util import load_data, preprocess_data
from unet import unet

# %%
# initialize input size and shape
INPUT_SIZE = (256, 256)
INPUT_SHAPE = (256, 256, 3) # color images, 3 channels

# %%
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import random

# load data
def load_data(dir_path):
    # dir_path = '../satellite-roads/train/'
    directory = os.listdir(dir_path)
    images = []
    masks = []

    for filename in directory:
        if filename.split('.')[1] == 'jpg':
            images.append(filename)
        elif filename.split('.')[1] == 'png':
            masks.append(filename)
    return np.array(images), np.array(masks)
dir_path = "training\\"
image_filenames, mask_filenames = load_data(dir_path)

# %%
# display the first 5 pairs of image and mask
random_indices = random.sample(range(0, len(image_filenames)), 5)
display_data(dir_path, image_filenames[random_indices], mask_filenames[random_indices])

# %%
# preprocess data
images, masks = preprocess_data(dir_path, image_filenames, mask_filenames, input_size=INPUT_SIZE, augmented=True)

# %%
# get shape
print('Shape of image data: ' + str(images.shape))
print('Shape of mask data: ' + str(masks.shape))
# Out:
# Shape of image data: (300, 256, 256, 3)
# Shape of mask data: (300, 256, 256, 1)

# %% [markdown]
# The dataset includes 300 images and 300 mask. The images have 3 channels while the masks have only 1.

# %%
# Split the dataset into training and validation sets
train_images, val_images, train_masks, val_masks = train_test_split(images, masks, test_size=0.3, random_state=42)
#train_images, test_images, train_masks, test_masks = train_test_split(train_images, train_masks, test_size=0.2, random_state=42)

# %%
# save check point
checkpoint = tf.keras.callbacks.ModelCheckpoint('models/save_best.h5', verbose=1, save_best_only=True)

# %% [markdown]
# <b>Given that we are predicting a binary mask, the output layer will be designed to accommodate this by having a size of 1.</b>

# %%
# Initialize the model
model = unet(INPUT_SHAPE, output_layer=1)
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_152 (Conv2D)         (None, 256, 256, 16)         448       ['input_9[0][0]']
#
#  batch_normalization_144 (B  (None, 256, 256, 16)         64        ['conv2d_152[0][0]']
#  atchNormalization)
#
#  conv2d_153 (Conv2D)         (None, 256, 256, 16)         2320      ['batch_normalization_144[0][0
#                                                                     ]']
#
#  batch_normalization_145 (B  (None, 256, 256, 16)         64        ['conv2d_153[0][0]']
#  atchNormalization)
#
#  dropout_72 (Dropout)        (None, 256, 256, 16)         0         ['batch_normalization_145[0][0
#                                                                     ]']
#
#  max_pooling2d_32 (MaxPooli  (None, 128, 128, 16)         0         ['dropout_72[0][0]']
#  ng2D)
#
#  conv2d_154 (Conv2D)         (None, 128, 128, 32)         4640      ['max_pooling2d_32[0][0]']
#
#  batch_normalization_146 (B  (None, 128, 128, 32)         128       ['conv2d_154[0][0]']
#  atchNormalization)
#
#  conv2d_155 (Conv2D)         (None, 128, 128, 32)         9248      ['batch_normalization_146[0][0
#                                                                     ]']
#
#  batch_normalization_147 (B  (None, 128, 128, 32)         128       ['conv2d_155[0][0]']
#  atchNormalization)
#
#  max_pooling2d_33 (MaxPooli  (None, 64, 64, 32)           0         ['batch_normalization_147[0][0
#  ng2D)                                                              ]']
#
#  conv2d_156 (Conv2D)         (None, 64, 64, 64)           18496     ['max_pooling2d_33[0][0]']
#
#  batch_normalization_148 (B  (None, 64, 64, 64)           256       ['conv2d_156[0][0]']
#  atchNormalization)
#
#  conv2d_157 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_148[0][0
#                                                                     ]']
#
#  batch_normalization_149 (B  (None, 64, 64, 64)           256       ['conv2d_157[0][0]']
#  atchNormalization)
#
#  max_pooling2d_34 (MaxPooli  (None, 32, 32, 64)           0         ['batch_normalization_149[0][0
#  ng2D)                                                              ]']
#
#  conv2d_158 (Conv2D)         (None, 32, 32, 128)          73856     ['max_pooling2d_34[0][0]']
#
#  batch_normalization_150 (B  (None, 32, 32, 128)          512       ['conv2d_158[0][0]']
#  atchNormalization)
#
#  conv2d_159 (Conv2D)         (None, 32, 32, 128)          147584    ['batch_normalization_150[0][0
#                                                                     ]']
#
#  batch_normalization_151 (B  (None, 32, 32, 128)          512       ['conv2d_159[0][0]']
#  atchNormalization)
#
#  max_pooling2d_35 (MaxPooli  (None, 16, 16, 128)          0         ['batch_normalization_151[0][0
#  ng2D)                                                              ]']
#
#  conv2d_160 (Conv2D)         (None, 16, 16, 256)          295168    ['max_pooling2d_35[0][0]']
#
#  batch_normalization_152 (B  (None, 16, 16, 256)          1024      ['conv2d_160[0][0]']
#  atchNormalization)
#
#  conv2d_161 (Conv2D)         (None, 16, 16, 256)          590080    ['batch_normalization_152[0][0
#                                                                     ]']
#
#  batch_normalization_153 (B  (None, 16, 16, 256)          1024      ['conv2d_161[0][0]']
#  atchNormalization)
#
#  dropout_76 (Dropout)        (None, 16, 16, 256)          0         ['batch_normalization_153[0][0
#                                                                     ]']
#
#  dropout_75 (Dropout)        (None, 32, 32, 128)          0         ['batch_normalization_151[0][0
#                                                                     ]']
#
#  conv2d_transpose_32 (Conv2  (None, 32, 32, 128)          131200    ['dropout_76[0][0]']
#  DTranspose)
#
#  concatenate_32 (Concatenat  (None, 32, 32, 256)          0         ['dropout_75[0][0]',
#  e)                                                                  'conv2d_transpose_32[0][0]']
#
#  dropout_77 (Dropout)        (None, 32, 32, 256)          0         ['concatenate_32[0][0]']
#
#  conv2d_162 (Conv2D)         (None, 32, 32, 128)          295040    ['dropout_77[0][0]']
#
#  batch_normalization_154 (B  (None, 32, 32, 128)          512       ['conv2d_162[0][0]']
#  atchNormalization)
#
#  conv2d_163 (Conv2D)         (None, 32, 32, 128)          147584    ['batch_normalization_154[0][0
#                                                                     ]']
#
#  batch_normalization_155 (B  (None, 32, 32, 128)          512       ['conv2d_163[0][0]']
#  atchNormalization)
#
#  dropout_74 (Dropout)        (None, 64, 64, 64)           0         ['batch_normalization_149[0][0
#                                                                     ]']
#
#  conv2d_transpose_33 (Conv2  (None, 64, 64, 64)           32832     ['batch_normalization_155[0][0
#  DTranspose)                                                        ]']
#
#  concatenate_33 (Concatenat  (None, 64, 64, 128)          0         ['dropout_74[0][0]',
#  e)                                                                  'conv2d_transpose_33[0][0]']
#
#  dropout_78 (Dropout)        (None, 64, 64, 128)          0         ['concatenate_33[0][0]']
#
#  conv2d_164 (Conv2D)         (None, 64, 64, 64)           73792     ['dropout_78[0][0]']
#
#  batch_normalization_156 (B  (None, 64, 64, 64)           256       ['conv2d_164[0][0]']
#  atchNormalization)
#
#  conv2d_165 (Conv2D)         (None, 64, 64, 64)           36928     ['batch_normalization_156[0][0
#                                                                     ]']
#
#  batch_normalization_157 (B  (None, 64, 64, 64)           256       ['conv2d_165[0][0]']
#  atchNormalization)
#
#  dropout_73 (Dropout)        (None, 128, 128, 32)         0         ['batch_normalization_147[0][0
#                                                                     ]']
#
#  conv2d_transpose_34 (Conv2  (None, 128, 128, 32)         8224      ['batch_normalization_157[0][0
#  DTranspose)                                                        ]']
#
#  concatenate_34 (Concatenat  (None, 128, 128, 64)         0         ['dropout_73[0][0]',
#  e)                                                                  'conv2d_transpose_34[0][0]']
#
#  dropout_79 (Dropout)        (None, 128, 128, 64)         0         ['concatenate_34[0][0]']
#
#  conv2d_166 (Conv2D)         (None, 128, 128, 32)         18464     ['dropout_79[0][0]']
#
#  batch_normalization_158 (B  (None, 128, 128, 32)         128       ['conv2d_166[0][0]']
#  atchNormalization)
#
#  conv2d_167 (Conv2D)         (None, 128, 128, 32)         9248      ['batch_normalization_158[0][0
#                                                                     ]']
#
#  batch_normalization_159 (B  (None, 128, 128, 32)         128       ['conv2d_167[0][0]']
#  atchNormalization)
#
#  conv2d_transpose_35 (Conv2  (None, 256, 256, 16)         2064      ['batch_normalization_159[0][0
#  DTranspose)                                                        ]']
#
#  concatenate_35 (Concatenat  (None, 256, 256, 32)         0         ['dropout_72[0][0]',
#  e)                                                                  'conv2d_transpose_35[0][0]']
#
#  dropout_80 (Dropout)        (None, 256, 256, 32)         0         ['concatenate_35[0][0]']
#
#  conv2d_168 (Conv2D)         (None, 256, 256, 16)         4624      ['dropout_80[0][0]']
#
#  batch_normalization_160 (B  (None, 256, 256, 16)         64        ['conv2d_168[0][0]']
#  atchNormalization)
#
#  conv2d_169 (Conv2D)         (None, 256, 256, 16)         2320      ['batch_normalization_160[0][0
#                                                                     ]']
#
#  batch_normalization_161 (B  (None, 256, 256, 16)         64        ['conv2d_169[0][0]']
#  atchNormalization)
#
#  conv2d_170 (Conv2D)         (None, 256, 256, 1)          17        ['batch_normalization_161[0][0
#                                                                     ]']
# ==================================================================================================
# Total params: 1946993 (7.43 MB)
# Trainable params: 1944049 (7.42 MB)
# Non-trainable params: 2944 (11.50 KB)
# __________________________________________________________________________________________________

# %%
# complie the model
model.compile(optimizer=Adam(learning_rate = 1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Learning Rate Scheduler: Reduce the learning rate when the validation loss plateaus
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %%
epochs = 50
#with tf.device("/GPU:0"):
history = model.fit(train_images, train_masks, batch_size=16, epochs=epochs, validation_data=(val_images, val_masks), callbacks=[checkpoint])#, early_stopping, lr_scheduler])
# Out:
# Epoch 1/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3391 - accuracy: 0.8976
# Epoch 1: val_loss improved from inf to 0.58586, saving model to models\save_best.h5
# 14/14 [==============================] - 32s 2s/step - loss: 0.3391 - accuracy: 0.8976 - val_loss: 0.5859 - val_accuracy: 0.7724
# Epoch 2/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3279 - accuracy: 0.9019
# Epoch 2: val_loss did not improve from 0.58586
# 14/14 [==============================] - 28s 2s/step - loss: 0.3279 - accuracy: 0.9019 - val_loss: 0.5937 - val_accuracy: 0.7728
# Epoch 3/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3164 - accuracy: 0.9068
# Epoch 3: val_loss improved from 0.58586 to 0.57154, saving model to models\save_best.h5
# 14/14 [==============================] - 29s 2s/step - loss: 0.3164 - accuracy: 0.9068 - val_loss: 0.5715 - val_accuracy: 0.7727
# Epoch 4/50
# 14/14 [==============================] - ETA: 0s - loss: 0.3101 - accuracy: 0.9117
# Epoch 4: val_loss improved from 0.57154 to 0.54183, saving model to models\save_best.h5
# 14/14 [==============================] - 29s 2s/step - loss: 0.3101 - accuracy: 0.9117 - val_loss: 0.5418 - val_accuracy: 0.7795
# Epoch 5/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.9137
# Epoch 5: val_loss did not improve from 0.54183
# 14/14 [==============================] - 31s 2s/step - loss: 0.2987 - accuracy: 0.9137 - val_loss: 0.5650 - val_accuracy: 0.7812
# Epoch 6/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2912 - accuracy: 0.9170
# Epoch 6: val_loss did not improve from 0.54183
# 14/14 [==============================] - 34s 2s/step - loss: 0.2912 - accuracy: 0.9170 - val_loss: 0.5914 - val_accuracy: 0.7769
# Epoch 7/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.9187
# Epoch 7: val_loss did not improve from 0.54183
# 14/14 [==============================] - 37s 3s/step - loss: 0.2864 - accuracy: 0.9187 - val_loss: 0.5918 - val_accuracy: 0.7786
# Epoch 8/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.9203
# Epoch 8: val_loss did not improve from 0.54183
# 14/14 [==============================] - 37s 3s/step - loss: 0.2781 - accuracy: 0.9203 - val_loss: 0.5891 - val_accuracy: 0.7788
# Epoch 9/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.9245
# Epoch 9: val_loss improved from 0.54183 to 0.52317, saving model to models\save_best.h5
# 14/14 [==============================] - 37s 3s/step - loss: 0.2700 - accuracy: 0.9245 - val_loss: 0.5232 - val_accuracy: 0.7951
# Epoch 10/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2645 - accuracy: 0.9245
# Epoch 10: val_loss did not improve from 0.52317
# 14/14 [==============================] - 38s 3s/step - loss: 0.2645 - accuracy: 0.9245 - val_loss: 0.5891 - val_accuracy: 0.7834
# Epoch 11/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2556 - accuracy: 0.9288
# Epoch 11: val_loss improved from 0.52317 to 0.48761, saving model to models\save_best.h5
# 14/14 [==============================] - 34s 2s/step - loss: 0.2556 - accuracy: 0.9288 - val_loss: 0.4876 - val_accuracy: 0.8139
# Epoch 12/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 0.9274
# Epoch 12: val_loss did not improve from 0.48761
# 14/14 [==============================] - 34s 2s/step - loss: 0.2567 - accuracy: 0.9274 - val_loss: 0.5335 - val_accuracy: 0.7976
# Epoch 13/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.9276
# Epoch 13: val_loss did not improve from 0.48761
# 14/14 [==============================] - 36s 3s/step - loss: 0.2533 - accuracy: 0.9276 - val_loss: 0.4881 - val_accuracy: 0.8092
# Epoch 14/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2419 - accuracy: 0.9308
# Epoch 14: val_loss improved from 0.48761 to 0.40910, saving model to models\save_best.h5
# 14/14 [==============================] - 38s 3s/step - loss: 0.2419 - accuracy: 0.9308 - val_loss: 0.4091 - val_accuracy: 0.8421
# Epoch 15/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9338
# Epoch 15: val_loss did not improve from 0.40910
# 14/14 [==============================] - 38s 3s/step - loss: 0.2347 - accuracy: 0.9338 - val_loss: 0.4402 - val_accuracy: 0.8340
# Epoch 16/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9339
# Epoch 16: val_loss did not improve from 0.40910
# 14/14 [==============================] - 38s 3s/step - loss: 0.2350 - accuracy: 0.9339 - val_loss: 0.4183 - val_accuracy: 0.8482
# Epoch 17/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2250 - accuracy: 0.9374
# Epoch 17: val_loss did not improve from 0.40910
# 14/14 [==============================] - 38s 3s/step - loss: 0.2250 - accuracy: 0.9374 - val_loss: 0.4472 - val_accuracy: 0.8364
# Epoch 18/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9387
# Epoch 18: val_loss improved from 0.40910 to 0.37445, saving model to models\save_best.h5
# 14/14 [==============================] - 37s 3s/step - loss: 0.2185 - accuracy: 0.9387 - val_loss: 0.3744 - val_accuracy: 0.8660
# Epoch 19/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2119 - accuracy: 0.9404
# Epoch 19: val_loss did not improve from 0.37445
# 14/14 [==============================] - 34s 2s/step - loss: 0.2119 - accuracy: 0.9404 - val_loss: 0.3908 - val_accuracy: 0.8605
# Epoch 20/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9392
# Epoch 20: val_loss improved from 0.37445 to 0.36612, saving model to models\save_best.h5
# 14/14 [==============================] - 38s 3s/step - loss: 0.2137 - accuracy: 0.9392 - val_loss: 0.3661 - val_accuracy: 0.8689
# Epoch 21/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9415
# Epoch 21: val_loss improved from 0.36612 to 0.32813, saving model to models\save_best.h5
# 14/14 [==============================] - 40s 3s/step - loss: 0.2058 - accuracy: 0.9415 - val_loss: 0.3281 - val_accuracy: 0.8866
# Epoch 22/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2004 - accuracy: 0.9428
# Epoch 22: val_loss improved from 0.32813 to 0.31214, saving model to models\save_best.h5
# 14/14 [==============================] - 35s 2s/step - loss: 0.2004 - accuracy: 0.9428 - val_loss: 0.3121 - val_accuracy: 0.8924
# Epoch 23/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9439
# Epoch 23: val_loss improved from 0.31214 to 0.30697, saving model to models\save_best.h5
# 14/14 [==============================] - 36s 3s/step - loss: 0.1967 - accuracy: 0.9439 - val_loss: 0.3070 - val_accuracy: 0.8965
# Epoch 24/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9440
# Epoch 24: val_loss improved from 0.30697 to 0.29984, saving model to models\save_best.h5
# 14/14 [==============================] - 34s 2s/step - loss: 0.1952 - accuracy: 0.9440 - val_loss: 0.2998 - val_accuracy: 0.9021
# Epoch 25/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1927 - accuracy: 0.9454
# Epoch 25: val_loss did not improve from 0.29984
# 14/14 [==============================] - 36s 3s/step - loss: 0.1927 - accuracy: 0.9454 - val_loss: 0.3264 - val_accuracy: 0.8998
# Epoch 26/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9460
# Epoch 26: val_loss did not improve from 0.29984
# 14/14 [==============================] - 33s 2s/step - loss: 0.1885 - accuracy: 0.9460 - val_loss: 0.3401 - val_accuracy: 0.8996
# Epoch 27/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9420
# Epoch 27: val_loss improved from 0.29984 to 0.29908, saving model to models\save_best.h5
# 14/14 [==============================] - 33s 2s/step - loss: 0.1945 - accuracy: 0.9420 - val_loss: 0.2991 - val_accuracy: 0.9040
# Epoch 28/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9437
# Epoch 28: val_loss did not improve from 0.29908
# 14/14 [==============================] - 32s 2s/step - loss: 0.1913 - accuracy: 0.9437 - val_loss: 0.3030 - val_accuracy: 0.9063
# Epoch 29/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9430
# Epoch 29: val_loss did not improve from 0.29908
# 14/14 [==============================] - 34s 2s/step - loss: 0.1877 - accuracy: 0.9430 - val_loss: 0.3123 - val_accuracy: 0.9062
# Epoch 30/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9479
# Epoch 30: val_loss improved from 0.29908 to 0.29212, saving model to models\save_best.h5
# 14/14 [==============================] - 33s 2s/step - loss: 0.1809 - accuracy: 0.9479 - val_loss: 0.2921 - val_accuracy: 0.9085
# Epoch 31/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1766 - accuracy: 0.9480
# Epoch 31: val_loss did not improve from 0.29212
# 14/14 [==============================] - 32s 2s/step - loss: 0.1766 - accuracy: 0.9480 - val_loss: 0.3011 - val_accuracy: 0.9085
# Epoch 32/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9494
# Epoch 32: val_loss did not improve from 0.29212
# 14/14 [==============================] - 32s 2s/step - loss: 0.1720 - accuracy: 0.9494 - val_loss: 0.3053 - val_accuracy: 0.9092
# Epoch 33/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1688 - accuracy: 0.9520
# Epoch 33: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.1688 - accuracy: 0.9520 - val_loss: 0.3151 - val_accuracy: 0.9095
# Epoch 34/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.9516
# Epoch 34: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.1670 - accuracy: 0.9516 - val_loss: 0.3144 - val_accuracy: 0.9096
# Epoch 35/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9511
# Epoch 35: val_loss did not improve from 0.29212
# 14/14 [==============================] - 34s 2s/step - loss: 0.1682 - accuracy: 0.9511 - val_loss: 0.3693 - val_accuracy: 0.9006
# Epoch 36/50
# 14/14 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9377
# Epoch 36: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.2005 - accuracy: 0.9377 - val_loss: 0.3352 - val_accuracy: 0.9021
# Epoch 37/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9463
# Epoch 37: val_loss did not improve from 0.29212
# 14/14 [==============================] - 32s 2s/step - loss: 0.1780 - accuracy: 0.9463 - val_loss: 0.3316 - val_accuracy: 0.9026
# Epoch 38/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9490
# Epoch 38: val_loss did not improve from 0.29212
# 14/14 [==============================] - 32s 2s/step - loss: 0.1682 - accuracy: 0.9490 - val_loss: 0.4011 - val_accuracy: 0.8984
# Epoch 39/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1579 - accuracy: 0.9533
# Epoch 39: val_loss did not improve from 0.29212
# 14/14 [==============================] - 32s 2s/step - loss: 0.1579 - accuracy: 0.9533 - val_loss: 0.3366 - val_accuracy: 0.9059
# Epoch 40/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9538
# Epoch 40: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.1543 - accuracy: 0.9538 - val_loss: 0.3342 - val_accuracy: 0.9074
# Epoch 41/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9536
# Epoch 41: val_loss did not improve from 0.29212
# 14/14 [==============================] - 34s 2s/step - loss: 0.1544 - accuracy: 0.9536 - val_loss: 0.3157 - val_accuracy: 0.9093
# Epoch 42/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9541
# Epoch 42: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.1532 - accuracy: 0.9541 - val_loss: 0.3124 - val_accuracy: 0.9098
# Epoch 43/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1522 - accuracy: 0.9547
# Epoch 43: val_loss did not improve from 0.29212
# 14/14 [==============================] - 32s 2s/step - loss: 0.1522 - accuracy: 0.9547 - val_loss: 0.3325 - val_accuracy: 0.9073
# Epoch 44/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9565
# Epoch 44: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.1459 - accuracy: 0.9565 - val_loss: 0.3471 - val_accuracy: 0.9066
# Epoch 45/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9567
# Epoch 45: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.1439 - accuracy: 0.9567 - val_loss: 0.3120 - val_accuracy: 0.9111
# Epoch 46/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9576
# Epoch 46: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.1425 - accuracy: 0.9576 - val_loss: 0.3188 - val_accuracy: 0.9115
# Epoch 47/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9579
# Epoch 47: val_loss did not improve from 0.29212
# 14/14 [==============================] - 32s 2s/step - loss: 0.1400 - accuracy: 0.9579 - val_loss: 0.3318 - val_accuracy: 0.9088
# Epoch 48/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9582
# Epoch 48: val_loss did not improve from 0.29212
# 14/14 [==============================] - 33s 2s/step - loss: 0.1395 - accuracy: 0.9582 - val_loss: 0.3085 - val_accuracy: 0.9127
# Epoch 49/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9590
# Epoch 49: val_loss did not improve from 0.29212
# 14/14 [==============================] - 39s 3s/step - loss: 0.1351 - accuracy: 0.9590 - val_loss: 0.3168 - val_accuracy: 0.9108
# Epoch 50/50
# 14/14 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9587
# Epoch 50: val_loss did not improve from 0.29212
# 14/14 [==============================] - 37s 3s/step - loss: 0.1356 - accuracy: 0.9587 - val_loss: 0.3005 - val_accuracy: 0.9128

# %%
loss, accuracy = model.evaluate(val_images, val_masks, batch_size=16, verbose=1)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 6/6 [==============================] - 3s 417ms/step - loss: 0.2989 - accuracy: 0.9135
# Test Loss: 0.2988571524620056
# Test Accuracy: 0.9134572148323059

# %%
# Accessing training and testing accuracy
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

epochs = range(1, epochs + 1)

# Plotting
plt.plot(epochs, train_accuracy, 'r', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Accessing training and Validation Loss
train_loss = history.history['loss']
val_Loss = history.history['val_loss']

epochs = range(1, 50 + 1)

# Plotting
plt.plot(epochs, train_loss, 'r', label='Training Loss')
plt.plot(epochs, val_Loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.save('models/roads_extraction.h5')

# %%
def extract_number(filename):
    return int(filename.split('_')[1].split('.')[0])
directory = os.listdir('New folder\\')
images_test = []
for i in directory:
    images_test.append(i)
    
sorted_images = sorted(images_test, key=extract_number)
test_images = np.array(sorted_images)

# %%
test_images
# Out:
# array(['test_1.png', 'test_2.png', 'test_3.png', 'test_4.png',
#        'test_5.png', 'test_6.png', 'test_7.png', 'test_8.png',
#        'test_9.png', 'test_10.png', 'test_11.png', 'test_12.png',
#        'test_13.png', 'test_14.png', 'test_15.png', 'test_16.png',
#        'test_17.png', 'test_18.png', 'test_19.png', 'test_20.png',
#        'test_21.png', 'test_22.png', 'test_23.png', 'test_24.png',
#        'test_25.png', 'test_26.png', 'test_27.png', 'test_28.png',
#        'test_29.png', 'test_30.png', 'test_31.png', 'test_32.png',
#        'test_33.png', 'test_34.png', 'test_35.png', 'test_36.png',
#        'test_37.png', 'test_38.png', 'test_39.png', 'test_40.png',
#        'test_41.png', 'test_42.png', 'test_43.png', 'test_44.png',
#        'test_45.png', 'test_46.png', 'test_47.png', 'test_48.png',
#        'test_49.png', 'test_50.png'], dtype='<U11')

# %%
def preprocess_data(root_path, images, input_size):
    image = []
    for img_file in images:
        img = load_img(root_path + img_file, target_size=input_size, color_mode='rgb')  
        # Convert image and mask to arrays
        img_array = img_to_array(img)
        img_array = img_array / 255.0
        # Append images and masks to the lists
        image.append(img_array)
    # Convert lists to numpy arrays
    images = np.array(image)
    return images

# %%
test = preprocess_data('New folder\\', test_iamges, input_size=INPUT_SIZE)
test
# Out:
# array([[[[0.19607843, 0.1764706 , 0.16470589],
#          [0.22352941, 0.19607843, 0.18039216],
#          [0.14901961, 0.14117648, 0.13725491],
#          ...,
#          [0.5529412 , 0.5294118 , 0.48235294],
#          [0.06666667, 0.05882353, 0.05490196],
#          [0.5568628 , 0.5372549 , 0.5019608 ]],
#
#         [[0.21568628, 0.1882353 , 0.17254902],
#          [0.21960784, 0.19607843, 0.18431373],
#          [0.11764706, 0.11372549, 0.10588235],
#          ...,
#          [0.52156866, 0.49019608, 0.44313726],
#          [0.5137255 , 0.4862745 , 0.44705883],
#          [0.54901963, 0.5176471 , 0.47058824]],
#
#         [[0.22745098, 0.21568628, 0.19607843],
#          [0.21960784, 0.20784314, 0.19215687],
#          [0.19607843, 0.18431373, 0.16862746],
#          ...,
#          [0.6117647 , 0.58431375, 0.5372549 ],
#          [0.6862745 , 0.6627451 , 0.60784316],
#          [0.48235294, 0.45490196, 0.40784314]],
#
#         ...,
#
#         [[0.5058824 , 0.4862745 , 0.4392157 ],
#          [0.45882353, 0.43529412, 0.3882353 ],
#          [0.44705883, 0.41960785, 0.38039216],
#          ...,
#          [0.31764707, 0.33333334, 0.30588236],
#          [0.30588236, 0.32156864, 0.29803923],
#          [0.30980393, 0.30980393, 0.29411766]],
#
#         [[0.50980395, 0.4862745 , 0.4392157 ],
#          [0.5411765 , 0.5176471 , 0.4745098 ],
#          [0.4       , 0.3764706 , 0.33333334],
#          ...,
#          [0.32941177, 0.34901962, 0.32156864],
#          [0.30980393, 0.3254902 , 0.29803923],
#          [0.3137255 , 0.31764707, 0.3019608 ]],
#
#         [[0.56078434, 0.5411765 , 0.49803922],
#          [0.35686275, 0.3372549 , 0.2901961 ],
#          [0.3882353 , 0.3764706 , 0.32941177],
#          ...,
#          [0.33333334, 0.34901962, 0.33333334],
#          [0.32941177, 0.34117648, 0.3254902 ],
#          [0.3254902 , 0.34509805, 0.32156864]]],
#
#
#        [[[0.5294118 , 0.5019608 , 0.45882353],
#          [0.48235294, 0.46666667, 0.42352942],
#          [0.52156866, 0.49803922, 0.4627451 ],
#          ...,
#          [0.35686275, 0.34117648, 0.31764707],
#          [0.33333334, 0.3254902 , 0.29803923],
#          [0.34901962, 0.32941177, 0.3019608 ]],
#
#         [[0.34117648, 0.3254902 , 0.30980393],
#          [0.3647059 , 0.35686275, 0.3372549 ],
#          [0.36862746, 0.35686275, 0.34509805],
#          ...,
#          [0.36078432, 0.3529412 , 0.3254902 ],
#          [0.35686275, 0.34509805, 0.31764707],
#          [0.38431373, 0.36078432, 0.3372549 ]],
#
#         [[0.3764706 , 0.3647059 , 0.34117648],
#          [0.38431373, 0.37254903, 0.34509805],
#          [0.38039216, 0.36862746, 0.34117648],
#          ...,
#          [0.4       , 0.3882353 , 0.36078432],
#          [0.3882353 , 0.38039216, 0.34901962],
#          [0.3882353 , 0.38039216, 0.34901962]],
#
#         ...,
#
#         [[0.5294118 , 0.50980395, 0.4745098 ],
#          [0.19215687, 0.22352941, 0.14901961],
#          [0.24313726, 0.2901961 , 0.19607843],
#          ...,
#          [0.41960785, 0.43137255, 0.43137255],
#          [0.44313726, 0.4509804 , 0.44313726],
#          [0.37254903, 0.38039216, 0.36862746]],
#
#         [[0.5137255 , 0.49411765, 0.45490196],
#          [0.21568628, 0.21960784, 0.19607843],
#          [0.25490198, 0.27058825, 0.23137255],
#          ...,
#          [0.40784314, 0.41568628, 0.40784314],
#          [0.45490196, 0.46666667, 0.46666667],
#          [0.34117648, 0.34509805, 0.32941177]],
#
#         [[0.04705882, 0.03137255, 0.05098039],
#          [0.04313726, 0.05098039, 0.05098039],
#          [0.02352941, 0.02745098, 0.03137255],
#          ...,
#          [0.43529412, 0.44313726, 0.4392157 ],
#          [0.48235294, 0.49411765, 0.49019608],
#          [0.49411765, 0.5058824 , 0.49803922]]],
#
#
#        [[[0.39607844, 0.3764706 , 0.34117648],
#          [0.40784314, 0.38039216, 0.3529412 ],
#          [0.42352942, 0.40392157, 0.38039216],
#          ...,
#          [0.5686275 , 0.5568628 , 0.5254902 ],
#          [0.46666667, 0.44705883, 0.41960785],
#          [0.18431373, 0.18039216, 0.16862746]],
#
#         [[0.36862746, 0.3529412 , 0.31764707],
#          [0.37254903, 0.36078432, 0.32156864],
#          [0.3764706 , 0.36078432, 0.32156864],
#          ...,
#          [0.3647059 , 0.34117648, 0.3254902 ],
#          [0.35686275, 0.34117648, 0.3254902 ],
#          [0.2784314 , 0.27058825, 0.25490198]],
#
#         [[0.3647059 , 0.3529412 , 0.31764707],
#          [0.3529412 , 0.3372549 , 0.31764707],
#          [0.36078432, 0.3372549 , 0.31764707],
#          ...,
#          [0.37254903, 0.3529412 , 0.32941177],
#          [0.3529412 , 0.34117648, 0.31764707],
#          [0.31764707, 0.30588236, 0.28235295]],
#
#         ...,
#
#         [[0.3882353 , 0.35686275, 0.34117648],
#          [0.36862746, 0.3529412 , 0.32156864],
#          [0.3529412 , 0.34509805, 0.3019608 ],
#          ...,
#          [0.16862746, 0.14901961, 0.1254902 ],
#          [0.22745098, 0.2       , 0.17254902],
#          [0.2509804 , 0.23137255, 0.19607843]],
#
#         [[0.39607844, 0.37254903, 0.34509805],
#          [0.36078432, 0.34509805, 0.30980393],
#          [0.37254903, 0.36078432, 0.31764707],
#          ...,
#          [0.28235295, 0.27058825, 0.23921569],
#          [0.28235295, 0.25490198, 0.22352941],
#          [0.27058825, 0.2509804 , 0.21960784]],
#
#         [[0.4       , 0.38431373, 0.34901962],
#          [0.4509804 , 0.43529412, 0.39607844],
#          [0.40784314, 0.3882353 , 0.36078432],
#          ...,
#          [0.2627451 , 0.24705882, 0.21960784],
#          [0.2784314 , 0.25490198, 0.22352941],
#          [0.27058825, 0.24313726, 0.21176471]]],
#
#
#        ...,
#
#
#        [[[0.50980395, 0.49411765, 0.43529412],
#          [0.5411765 , 0.52156866, 0.47058824],
#          [0.1882353 , 0.18039216, 0.14117648],
#          ...,
#          [0.14509805, 0.14117648, 0.16078432],
#          [0.26666668, 0.2627451 , 0.25882354],
#          [0.13725491, 0.1254902 , 0.11372549]],
#
#         [[0.5921569 , 0.58431375, 0.5294118 ],
#          [0.47058824, 0.46666667, 0.42352942],
#          [0.01960784, 0.01960784, 0.03529412],
#          ...,
#          [0.23137255, 0.22745098, 0.22745098],
#          [0.01176471, 0.00784314, 0.00784314],
#          [0.5019608 , 0.49803922, 0.49803922]],
#
#         [[0.5647059 , 0.5529412 , 0.49803922],
#          [0.        , 0.        , 0.        ],
#          [0.11764706, 0.12941177, 0.1254902 ],
#          ...,
#          [0.8509804 , 0.8509804 , 0.8352941 ],
#          [0.8117647 , 0.8156863 , 0.8       ],
#          [0.63529414, 0.6431373 , 0.61960787]],
#
#         ...,
#
#         [[0.02352941, 0.03137255, 0.03921569],
#          [0.1764706 , 0.18431373, 0.18431373],
#          [0.01960784, 0.01960784, 0.03529412],
#          ...,
#          [0.39607844, 0.36862746, 0.29803923],
#          [0.3764706 , 0.34901962, 0.29411766],
#          [0.34509805, 0.31764707, 0.2627451 ]],
#
#         [[0.24313726, 0.23921569, 0.20784314],
#          [0.39607844, 0.36078432, 0.3137255 ],
#          [0.39215687, 0.3647059 , 0.32941177],
#          ...,
#          [0.4117647 , 0.3882353 , 0.30980393],
#          [0.41568628, 0.39215687, 0.31764707],
#          [0.32941177, 0.3019608 , 0.24705882]],
#
#         [[0.34509805, 0.3254902 , 0.29803923],
#          [0.43529412, 0.37254903, 0.2901961 ],
#          [0.43529412, 0.36862746, 0.28627452],
#          ...,
#          [0.42352942, 0.4       , 0.34117648],
#          [0.39215687, 0.36862746, 0.30588236],
#          [0.4117647 , 0.38431373, 0.30980393]]],
#
#
#        [[[0.46666667, 0.4627451 , 0.42352942],
#          [0.46666667, 0.44313726, 0.42352942],
#          [0.5058824 , 0.48235294, 0.44313726],
#          ...,
#          [0.22745098, 0.25490198, 0.19607843],
#          [0.20784314, 0.23137255, 0.16862746],
#          [0.2       , 0.2       , 0.16078432]],
#
#         [[0.49803922, 0.48235294, 0.4627451 ],
#          [0.4117647 , 0.3882353 , 0.35686275],
#          [0.49803922, 0.47058824, 0.4392157 ],
#          ...,
#          [0.24705882, 0.27450982, 0.20784314],
#          [0.27450982, 0.30588236, 0.23529412],
#          [0.22352941, 0.23921569, 0.1764706 ]],
#
#         [[0.08627451, 0.08235294, 0.08235294],
#          [0.45882353, 0.43529412, 0.40784314],
#          [0.47843137, 0.47058824, 0.42745098],
#          ...,
#          [0.09019608, 0.12156863, 0.05882353],
#          [0.15294118, 0.19607843, 0.09803922],
#          [0.23529412, 0.27058825, 0.17254902]],
#
#         ...,
#
#         [[0.3764706 , 0.3882353 , 0.32941177],
#          [0.3137255 , 0.34117648, 0.26666668],
#          [0.28235295, 0.32156864, 0.23529412],
#          ...,
#          [0.43529412, 0.39215687, 0.34117648],
#          [0.40784314, 0.38431373, 0.34901962],
#          [0.654902  , 0.63529414, 0.57254905]],
#
#         [[0.32156864, 0.34509805, 0.28235295],
#          [0.3647059 , 0.39607844, 0.30980393],
#          [0.36078432, 0.39607844, 0.30588236],
#          ...,
#          [0.3529412 , 0.3254902 , 0.2784314 ],
#          [0.72156864, 0.69803923, 0.6431373 ],
#          [0.60784316, 0.58431375, 0.53333336]],
#
#         [[0.38431373, 0.4       , 0.32156864],
#          [0.38431373, 0.39607844, 0.3372549 ],
#          [0.28235295, 0.29803923, 0.25490198],
#          ...,
#          [0.7529412 , 0.7294118 , 0.6627451 ],
#          [0.6       , 0.5803922 , 0.52156866],
#          [0.61960787, 0.59607846, 0.54901963]]],
#
#
#        [[[0.2509804 , 0.2509804 , 0.23529412],
#          [0.11372549, 0.10980392, 0.10588235],
#          [0.6313726 , 0.6431373 , 0.627451  ],
#          ...,
#          [0.60784316, 0.62352943, 0.60784316],
#          [0.5803922 , 0.5921569 , 0.57254905],
#          [0.6156863 , 0.627451  , 0.60784316]],
#
#         [[0.16470589, 0.15686275, 0.16078432],
#          [0.39215687, 0.39607844, 0.36078432],
#          [0.23921569, 0.23137255, 0.2       ],
#          ...,
#          [0.08627451, 0.09019608, 0.09411765],
#          [0.09803922, 0.09803922, 0.10588235],
#          [0.12156863, 0.1254902 , 0.12941177]],
#
#         [[0.3372549 , 0.34509805, 0.32156864],
#          [0.6431373 , 0.63529414, 0.58431375],
#          [0.39215687, 0.35686275, 0.29803923],
#          ...,
#          [0.2784314 , 0.28627452, 0.28627452],
#          [0.29411766, 0.30980393, 0.3019608 ],
#          [0.29803923, 0.29803923, 0.2784314 ]],
#
#         ...,
#
#         [[0.78431374, 0.78039217, 0.73333335],
#          [0.7490196 , 0.73333335, 0.6784314 ],
#          [0.2509804 , 0.2509804 , 0.20784314],
#          ...,
#          [0.1882353 , 0.19215687, 0.1882353 ],
#          [0.50980395, 0.49803922, 0.44705883],
#          [0.38039216, 0.37254903, 0.31764707]],
#
#         [[0.5019608 , 0.5019608 , 0.45490196],
#          [0.        , 0.        , 0.        ],
#          [0.2901961 , 0.30588236, 0.24313726],
#          ...,
#          [0.2       , 0.21176471, 0.19607843],
#          [0.03137255, 0.04313726, 0.03921569],
#          [0.5294118 , 0.5137255 , 0.4627451 ]],
#
#         [[0.14117648, 0.14117648, 0.10588235],
#          [0.30588236, 0.32941177, 0.25882354],
#          [0.3647059 , 0.32941177, 0.30980393],
#          ...,
#          [0.1764706 , 0.1882353 , 0.1882353 ],
#          [0.1882353 , 0.20392157, 0.2       ],
#          [0.05098039, 0.05882353, 0.05490196]]]], dtype=float32)

# %%
prediction = model.predict(test)
prediction
# Out:
# 2/2 [==============================] - 2s 517ms/step
# array([[[[0.37860677],
#          [0.23395285],
#          [0.15094687],
#          ...,
#          [0.41934606],
#          [0.2732304 ],
#          [0.37643856]],
#
#         [[0.2213609 ],
#          [0.07966595],
#          [0.10429171],
#          ...,
#          [0.39623892],
#          [0.23014311],
#          [0.24951895]],
#
#         [[0.21963568],
#          [0.11338907],
#          [0.09867649],
#          ...,
#          [0.3823965 ],
#          [0.33974516],
#          [0.35089612]],
#
#         ...,
#
#         [[0.64143604],
#          [0.74318737],
#          [0.85159504],
#          ...,
#          [0.2088542 ],
#          [0.1775963 ],
#          [0.23103403]],
#
#         [[0.45300838],
#          [0.5811321 ],
#          [0.7215558 ],
#          ...,
#          [0.18373166],
#          [0.14561729],
#          [0.23281561]],
#
#         [[0.5009485 ],
#          [0.53792953],
#          [0.6452913 ],
#          ...,
#          [0.22254153],
#          [0.2579578 ],
#          [0.4250132 ]]],
#
#
#        [[[0.63911766],
#          [0.6291491 ],
#          [0.73160344],
#          ...,
#          [0.5110584 ],
#          [0.39966455],
#          [0.39368802]],
#
#         [[0.59115726],
#          [0.6919085 ],
#          [0.8178705 ],
#          ...,
#          [0.58716345],
#          [0.40326118],
#          [0.33277872]],
#
#         [[0.67217267],
#          [0.81492287],
#          [0.9167042 ],
#          ...,
#          [0.66066134],
#          [0.4372216 ],
#          [0.43646294]],
#
#         ...,
#
#         [[0.18912485],
#          [0.10939714],
#          [0.08551323],
#          ...,
#          [0.21355313],
#          [0.16553295],
#          [0.26037273]],
#
#         [[0.2198801 ],
#          [0.11072355],
#          [0.10379315],
#          ...,
#          [0.20284481],
#          [0.13169329],
#          [0.24402463]],
#
#         [[0.3967513 ],
#          [0.2708112 ],
#          [0.21448165],
#          ...,
#          [0.23378427],
#          [0.302836  ],
#          [0.47526804]]],
#
#
#        [[[0.51697844],
#          [0.32992995],
#          [0.3773115 ],
#          ...,
#          [0.6690247 ],
#          [0.5277702 ],
#          [0.44754016]],
#
#         [[0.30404255],
#          [0.20210563],
#          [0.21635345],
#          ...,
#          [0.7131309 ],
#          [0.5632729 ],
#          [0.45348838]],
#
#         [[0.3403198 ],
#          [0.21470885],
#          [0.25669685],
#          ...,
#          [0.82396555],
#          [0.6881002 ],
#          [0.6541659 ]],
#
#         ...,
#
#         [[0.61038625],
#          [0.7137634 ],
#          [0.8507712 ],
#          ...,
#          [0.5195372 ],
#          [0.39252457],
#          [0.33039263]],
#
#         [[0.46458408],
#          [0.58702856],
#          [0.768485  ],
#          ...,
#          [0.378184  ],
#          [0.28798565],
#          [0.30711994]],
#
#         [[0.53940916],
#          [0.55204946],
#          [0.6766778 ],
#          ...,
#          [0.32977778],
#          [0.37553945],
#          [0.45299384]]],
#
#
#        ...,
#
#
#        [[[0.60158956],
#          [0.4121005 ],
#          [0.561314  ],
#          ...,
#          [0.12773435],
#          [0.19049634],
#          [0.33285484]],
#
#         [[0.47540385],
#          [0.49767464],
#          [0.6464489 ],
#          ...,
#          [0.06576885],
#          [0.0512427 ],
#          [0.19962122]],
#
#         [[0.50288796],
#          [0.569945  ],
#          [0.7449304 ],
#          ...,
#          [0.06592689],
#          [0.04655434],
#          [0.16545086]],
#
#         ...,
#
#         [[0.18962897],
#          [0.05193124],
#          [0.0568549 ],
#          ...,
#          [0.5987151 ],
#          [0.35744566],
#          [0.33247808]],
#
#         [[0.18802062],
#          [0.0709406 ],
#          [0.06241617],
#          ...,
#          [0.40682226],
#          [0.30966306],
#          [0.30227935]],
#
#         [[0.37309858],
#          [0.15776289],
#          [0.1455569 ],
#          ...,
#          [0.36769134],
#          [0.39083984],
#          [0.48988464]]],
#
#
#        [[[0.5393666 ],
#          [0.39987773],
#          [0.49436608],
#          ...,
#          [0.2561411 ],
#          [0.2448863 ],
#          [0.30168688]],
#
#         [[0.36919188],
#          [0.25852767],
#          [0.54595745],
#          ...,
#          [0.19799806],
#          [0.18690063],
#          [0.23978302]],
#
#         [[0.39101696],
#          [0.31891507],
#          [0.6540563 ],
#          ...,
#          [0.18813457],
#          [0.16005778],
#          [0.21222326]],
#
#         ...,
#
#         [[0.18539667],
#          [0.09230582],
#          [0.07792915],
#          ...,
#          [0.27873135],
#          [0.17112222],
#          [0.25058267]],
#
#         [[0.182911  ],
#          [0.09920637],
#          [0.09484078],
#          ...,
#          [0.1825256 ],
#          [0.17310487],
#          [0.21278453]],
#
#         [[0.35348213],
#          [0.22313288],
#          [0.15561555],
#          ...,
#          [0.21830432],
#          [0.23486929],
#          [0.44447184]]],
#
#
#        [[[0.55468065],
#          [0.29875752],
#          [0.32880273],
#          ...,
#          [0.36219764],
#          [0.29059863],
#          [0.32141978]],
#
#         [[0.34328443],
#          [0.20144165],
#          [0.28857312],
#          ...,
#          [0.30744076],
#          [0.19637491],
#          [0.28890115]],
#
#         [[0.35683718],
#          [0.2448167 ],
#          [0.37362444],
#          ...,
#          [0.43384457],
#          [0.24177316],
#          [0.28755826]],
#
#         ...,
#
#         [[0.32707325],
#          [0.18709543],
#          [0.2571051 ],
#          ...,
#          [0.07848875],
#          [0.15681718],
#          [0.1893976 ]],
#
#         [[0.2759035 ],
#          [0.19448395],
#          [0.18379228],
#          ...,
#          [0.08233106],
#          [0.1050745 ],
#          [0.21355072]],
#
#         [[0.46021074],
#          [0.3588078 ],
#          [0.25591186],
#          ...,
#          [0.23735009],
#          [0.23868892],
#          [0.3549624 ]]]], dtype=float32)

# %%
import numpy as np
import cv2
import os
from PIL import Image

# Directory where you want to save the mask images
output_masks_directory = "test_set_masks"

# Ensure output directory exists
if not os.path.exists(output_masks_directory):
    os.makedirs(output_masks_directory)

# Loop through each image in the batch
for i, prediction in enumerate(predictions):
    if prediction.ndim == 3:  # (height, width, 1)
        prediction = np.squeeze(prediction, axis=-1) 

    # Apply threshold to convert probabilities to binary (0 or 1)
    mask = (prediction > 0.5).astype(np.uint8)

    # Create the mask image (black for roads, white for background)
    masked_image = np.zeros((mask.shape[0], mask.shape[1], 3), dtype=np.uint8)
    masked_image[mask == 1] = [0, 0, 0]  # black for road pixels
    masked_image[mask == 0] = [255, 255, 255]  # white for background pixels

    # Save the generated mask image
    output_mask_path = os.path.join(output_masks_directory, f"mask_{i+1}.png")
    cv2.imwrite(output_mask_path, masked_image)


print("Masks generated and saved successfully for all images.")
# Out:
# Masks generated and saved successfully for all images.

# %%
directory = os.listdir('test_set_masks\\')
masks_test = []
for i in directory:
    masks_test.append(i)
sorted_masks = sorted(masks_test, key=extract_number)
test_masks = np.array(sorted_masks)    
random_indices = random.sample(range(0, len(test_images)), 5)
display_data('test_set\\', test_images[random_indices], test_masks[random_indices])

# %%
import os
import numpy as np
import matplotlib.image as mpimg
import re

# percentage of pixels > 1 required to assign a foreground label to a patch
foreground_threshold = 0.25

# assign a label to a patch
def patch_to_label(patch):
    df = np.mean(patch)
    if df > foreground_threshold:
        return 1
    else:
        return 0

def mask_to_submission_strings(full_path, image_filename):
    """Reads a single image and outputs the strings that should go into the submission file"""
    # Extracting the image number from the filename (e.g., "mask_1.png" becomes 1)
    img_number = int(re.search(r"(\d+)", image_filename).group(0))
    im = mpimg.imread(full_path)
    
    # Check the image size
    image_height, image_width = im.shape[:2]
    patch_size = 16
    
    # Ensure that we're processing patches up to 592 for all images (image size must be at least 608x608)
    for j in range(0, image_width, patch_size):
        for i in range(0, image_height, patch_size):
            if i <= 592 and j <= 592:  # Process patches up to (592, 592)
                patch = im[i:i + patch_size, j:j + patch_size]
                label = patch_to_label(patch)
                # Formatting the output as "001_0_0,1"
                yield("{:03d}_{},{} ,{}".format(img_number, j, i, label))

def masks_to_submission(submission_filename, submission_mask_path, image_filenames):
    """Converts images into a submission file"""
    with open(submission_filename, 'w') as f:
        f.write('id,prediction\n')
        for fn in image_filenames:
            path = os.path.join(submission_mask_path, fn)
            f.writelines('{}\n'.format(s)
                         for s in mask_to_submission_strings(path, fn))

def submit():
    submission_filename = 'h4.csv'
    submission_mask_path = 'test_set_masks/'
    # Sorting filenames based on the number after 'mask_' (e.g., "mask_1.png" -> 1)
    image_names = os.listdir(submission_mask_path)
    image_names.sort(key=lambda x: int(re.search(r"(\d+)", x).group(0)))
    
    # Process all images in the mask directory
    masks_to_submission(submission_filename, submission_mask_path, image_names)


submit()

# %%
import numpy as np
from sklearn.metrics import f1_score

def compute_f1_score(pred_mask, true_mask):
    """Compute F1 score for a single mask (predicted vs ground truth)"""
    # Flatten the 2D masks to 1D arrays
    pred_mask_flat = pred_mask.flatten()
    true_mask_flat = true_mask.flatten()

    # Compute F1 score using sklearn
    return f1_score(true_mask_flat, pred_mask_flat)

def evaluate_f1_score(pred_masks, true_masks):
    """Evaluate the F1 score across a dataset of masks"""
    f1_scores = []
    for pred_mask, true_mask in zip(pred_masks, true_masks):
        f1 = compute_f1_score(pred_mask, true_mask)
        f1_scores.append(f1)
    
    # Return the average F1 score across all images
    return np.mean(f1_scores)


# Calculate the average F1 score
average_f1 = evaluate_f1_score(pred_masks, true_masks)
print(f'Average F1 Score: {average_f1}')
